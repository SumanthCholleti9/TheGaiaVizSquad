# %%
import pandas as pd

# %%
data = {
'Indicator': ['1.1', '1.1', '1.1', '1.1', '1.2'],
    'SeriesCode': ['S1', 'S1', 'S2', 'S2', 'S3'],
    'SeriesDescription': ['series 1', 'series 1', 'series 2', 'series 2', 'series3'],
    'GeoAreaCode': ['g1', 'g1', 'g2', 'g2', 'g3'],
    'GeoAreaName': ['Albania', 'Albania', 'Malawi', 'Malawi', 'Malawi'],
    'TimePeriod': [2021, 2022, 2021, 2022, 2023],
    'Value': [5.6, 6.8, 4, 5, 1],
    'Country_Check': ['Country', 'Country', 'Country', 'Country', 'Country'],
    'Latitude': [41, 41, -13.5, -13.5, -13.5],
    'Longitude': [20, 20, 34, 34, 34]
}


# Creating the DataFrame
df = pd.DataFrame(data)

# %%
df
# Out:
#   Indicator SeriesCode SeriesDescription GeoAreaCode GeoAreaName  TimePeriod  \
# 0       1.1         S1          series 1          g1     Albania        2021
# 1       1.1         S1          series 1          g1     Albania        2022
# 2       1.1         S2          series 2          g2      Malawi        2021
# 3       1.1         S2          series 2          g2      Malawi        2022
# 4       1.2         S3           series3          g3      Malawi        2023
#
#    Value Country_Check  Latitude  Longitude
# 0    5.6       Country      41.0         20
# 1    6.8       Country      41.0         20
# 2    4.0       Country     -13.5         34
# 3    5.0       Country     -13.5         34
# 4    1.0       Country     -13.5         34

# %%
# Create a new dataframe
cdict_node = {}
cdict_tag = {}

c_ind_dict_node = {}
c_ind_dict_tag = {}

ser_dict_node = {}
ser_dict_tag = {}

ser_year_node = {}
ser_year_tag = {}

node_num=1
ind_node_num = 100
ser_node_num = 1000
ser_year_num = 5000

for index, row in df.iterrows():
    ind = row['Indicator']
    ind_series = row['SeriesCode']
    country = row['GeoAreaName']
    year = row['TimePeriod']
    val = row['Value']
    lat = row['Latitude']
    long = row['Longitude']
    
    cdict_node[country] = {
        'np_node_id': node_num,
        'type': 5,
        'np_data_id': node_num,
        'selected':0,
        'parent_id':0,
        'branch_level':1,
        'child_id':0,
        'np_tag_id':node_num,
        'np_palette_id':0,
        'np_ch_in_id':0,
        'np_ch_out_id':0,
        'ch_sync_time':0,
        'np_palette_id_alt':0,
        'np_color_id_alt':19,
        'aux_a_x':330,
        'aux_a_y':1,
        'aux_a_z':0.01,
        'aux_b_x':0,
        'aux_b_y':1,
        'aux_b_z':1,
        'color_alpha_alt':255,
        'rotate_vec_x':0,
        'rotate_vec_y':1,
        'rotate_vec_z':0,
        'rotate_vec_s':0,
        'scale_x':5.5,
        'scale_y':5.5,
        'scale_z':5.5,
        'translate_x':long,
        'translate_y':lat,
        'translate_z':0,
        'tag_offset_x':0,
        'tag_offset_y':0,
        'tag_offset_z':5.5,
        'rotate_rate_x':0,
        'rotate_rate_y':0,
        'rotate_rate_z':0,
        'rotate_x':0,
        'rotate_y':0,
        'rotate_z':0,
        'scale_rate_x':0,
        'scale_rate_y':0,
        'scale_rate_z':0,
        'translate_rate_x':0,
        'translate_rate_y':0,
        'translate_rate_z':0,
        'translate_vec_x':0,
        'translate_vec_y':0,
        'translate_vec_z':0,
        'np_material_id':0,
        'np_geometry_id':16,
        'line_width':1,
        'point_size':0,
        'ratio':0.1,
        'np_color_id':255,
        'color_r':127,
        'color_g':127,
        'color_b':127,
        'color_a':255,
        'color_fade':0,
        'np_texture_id':0,
        'hide':0,
        'freeze':0,
        'np_topo_id':5,
        'subspace':0,
        'auto_zoom_x':0,
        'auto_zoom_y':0,
        'auto_zoom_z':0,
        'trigger_hi_x':0,
        'trigger_hi_y':0,
        'trigger_hi_z':0,
        'trigger_lo_x':0,
        'trigger_lo_y':0,
        'trigger_lo_z':1,
        'set_hi_x':0,
        'set_hi_y':0,
        'set_hi_z':0,
        'set_lo_x':0,
        'set_lo_y':0,
        'set_lo_z':0,
        'proximity_x':0,
        'proximity_y':0,
        'proximity_z':0,
        'proximity_mode_x':0,
        'proximity_mode_y':0,
        'proximity_mode_z':0,
        'segments_x':12,
        'segments_y':6,
        'segments_z':1,
        'tag_mode':65536017,
        'np_format_id':0,
        'np_table_id':node_num,
        'record_id':node_num,
        'size':420 
        }


    cdict_tag[country] = {'np_tag_id':node_num,
                            'record_id':node_num,
                            'table_id': node_num,
                            'title': country,
                            'description': country
                          }

    node_num += 1

    c_ind_dict_node[country] = {
        'np_node_id': ind_node_num,
        'type': 5,
        'np_data_id': ind_node_num,
        'selected':0,
        'parent_id': cdict_node[country]['np_node_id'],
        'branch_level':2,
        'child_id':0,
        'np_tag_id':ind_node_num,
        'np_palette_id':0,
        'np_ch_in_id':0,
        'np_ch_out_id':0,
        'ch_sync_time':0,
        'np_palette_id_alt':0,
        'np_color_id_alt':19,
        'aux_a_x':330,
        'aux_a_y':1,
        'aux_a_z':0.01,
        'aux_b_x':0,
        'aux_b_y':1,
        'aux_b_z':1,
        'color_alpha_alt':255,
        'rotate_vec_x':0,
        'rotate_vec_y':1,
        'rotate_vec_z':0,
        'rotate_vec_s':0,
        'scale_x':0.8,
        'scale_y':0.8,
        'scale_z':0.8,
        'translate_x':0,
        'translate_y':0,
        'translate_z':0,
        'tag_offset_x':0,
        'tag_offset_y':1,
        'tag_offset_z':0,
        'rotate_rate_x':0,
        'rotate_rate_y':0,
        'rotate_rate_z':0,
        'rotate_x':0,
        'rotate_y':0,
        'rotate_z':0,
        'scale_rate_x':0,
        'scale_rate_y':0,
        'scale_rate_z':0,
        'translate_rate_x':0,
        'translate_rate_y':0,
        'translate_rate_z':0,
        'translate_vec_x':0,
        'translate_vec_y':0,
        'translate_vec_z':0,
        'np_material_id':0,
        'np_geometry_id':7,
        'line_width':1,
        'point_size':0,
        'ratio':0.1,
        'np_color_id':1,
        'color_r':0,
        'color_g':255,
        'color_b':0,
        'color_a':255,
        'color_fade':0,
        'np_texture_id':0,
        'hide':0,
        'freeze':0,
        'np_topo_id':3,
        'subspace':0,
        'auto_zoom_x':0,
        'auto_zoom_y':0,
        'auto_zoom_z':0,
        'trigger_hi_x':0,
        'trigger_hi_y':0,
        'trigger_hi_z':0,
        'trigger_lo_x':0,
        'trigger_lo_y':0,
        'trigger_lo_z':1,
        'set_hi_x':0,
        'set_hi_y':0,
        'set_hi_z':0,
        'set_lo_x':0,
        'set_lo_y':0,
        'set_lo_z':0,
        'proximity_x':0,
        'proximity_y':0,
        'proximity_z':0,
        'proximity_mode_x':0,
        'proximity_mode_y':0,
        'proximity_mode_z':0,
        'segments_x':12,
        'segments_y':6,
        'segments_z':1,
        'tag_mode':65536017,
        'np_format_id':0,
        'np_table_id':ind_node_num,
        'record_id':ind_node_num,
        'size':420 

    }

    c_ind_dict_tag[country] = {
                            'np_tag_id':ind_node_num,
                            'record_id':ind_node_num,
                            'table_id': ind_node_num,
                            'title': ind,
                            'description': ind + " - " + country
    }

    ind_node_num += 1

    ser_dict_node[country] = {
        'np_node_id': ser_node_num,
        'type': 5,
        'np_data_id': ser_node_num,
        'selected':0,
        'parent_id': c_ind_dict_node[country]['np_node_id'],
        'branch_level':3,
        'child_id':0,
        'np_tag_id':ser_node_num,
        'np_palette_id':0,
        'np_ch_in_id':0,
        'np_ch_out_id':0,
        'ch_sync_time':0,
        'np_palette_id_alt':0,
        'np_color_id_alt':19,
        'aux_a_x':330,
        'aux_a_y':1,
        'aux_a_z':0.01,
        'aux_b_x':0,
        'aux_b_y':1,
        'aux_b_z':1,
        'color_alpha_alt':255,
        'rotate_vec_x':0,
        'rotate_vec_y':1,
        'rotate_vec_z':0,
        'rotate_vec_s':0,
        'scale_x':0.8,
        'scale_y':0.8,
        'scale_z':0.8,
        'translate_x':0,
        'translate_y':0,
        'translate_z':0,
        'tag_offset_x':0,
        'tag_offset_y':1,
        'tag_offset_z':0,
        'rotate_rate_x':0,
        'rotate_rate_y':0,
        'rotate_rate_z':0,
        'rotate_x':0,
        'rotate_y':0,
        'rotate_z':0,
        'scale_rate_x':0,
        'scale_rate_y':0,
        'scale_rate_z':0,
        'translate_rate_x':0,
        'translate_rate_y':0,
        'translate_rate_z':0,
        'translate_vec_x':0,
        'translate_vec_y':0,
        'translate_vec_z':0,
        'np_material_id':0,
        'np_geometry_id':7,
        'line_width':1,
        'point_size':0,
        'ratio':0.1,
        'np_color_id':2,
        'color_r':255,
        'color_g':0,
        'color_b':0,
        'color_a':255,
        'color_fade':0,
        'np_texture_id':0,
        'hide':0,
        'freeze':0,
        'np_topo_id':3,
        'subspace':0,
        'auto_zoom_x':0,
        'auto_zoom_y':0,
        'auto_zoom_z':0,
        'trigger_hi_x':0,
        'trigger_hi_y':0,
        'trigger_hi_z':0,
        'trigger_lo_x':0,
        'trigger_lo_y':0,
        'trigger_lo_z':1,
        'set_hi_x':0,
        'set_hi_y':0,
        'set_hi_z':0,
        'set_lo_x':0,
        'set_lo_y':0,
        'set_lo_z':0,
        'proximity_x':0,
        'proximity_y':0,
        'proximity_z':0,
        'proximity_mode_x':0,
        'proximity_mode_y':0,
        'proximity_mode_z':0,
        'segments_x':12,
        'segments_y':6,
        'segments_z':1,
        'tag_mode':65536017,
        'np_format_id':0,
        'np_table_id':ser_node_num,
        'record_id':ser_node_num,
        'size':420 

    }

    ser_dict_tag[country] = {
                            'np_tag_id':ser_node_num,
                            'record_id':ser_node_num,
                            'table_id': ser_node_num,
                            'title': ind_series,
                            'description': ind + " - " + ind_series
    }

    ser_node_num += 1

    ser_year_node[country] = {
        'np_node_id': ser_year_num,
        'type': 5,
        'np_data_id': ser_year_num,
        'selected':0,
        'parent_id': ser_dict_node[country]['np_node_id'],
        'branch_level':4,
        'child_id':0,
        'np_tag_id':ser_year_num,
        'np_palette_id':0,
        'np_ch_in_id':0,
        'np_ch_out_id':0,
        'ch_sync_time':0,
        'np_palette_id_alt':0,
        'np_color_id_alt':19,
        'aux_a_x':330,
        'aux_a_y':1,
        'aux_a_z':0.01,
        'aux_b_x':0,
        'aux_b_y':1,
        'aux_b_z':1,
        'color_alpha_alt':255,
        'rotate_vec_x':0,
        'rotate_vec_y':1,
        'rotate_vec_z':0,
        'rotate_vec_s':0,
        'scale_x':0.8,
        'scale_y':0.8,
        'scale_z':0.8,
        'translate_x':0,
        'translate_y':0,
        'translate_z':0,
        'tag_offset_x':0,
        'tag_offset_y':1,
        'tag_offset_z':0,
        'rotate_rate_x':0,
        'rotate_rate_y':0,
        'rotate_rate_z':0,
        'rotate_x':0,
        'rotate_y':0,
        'rotate_z':0,
        'scale_rate_x':0,
        'scale_rate_y':0,
        'scale_rate_z':0,
        'translate_rate_x':0,
        'translate_rate_y':0,
        'translate_rate_z':0,
        'translate_vec_x':0,
        'translate_vec_y':0,
        'translate_vec_z':0,
        'np_material_id':0,
        'np_geometry_id':7,
        'line_width':1,
        'point_size':0,
        'ratio':0.1,
        'np_color_id':3,
        'color_r':0,
        'color_g':0,
        'color_b':255,
        'color_a':255,
        'color_fade':0,
        'np_texture_id':0,
        'hide':0,
        'freeze':0,
        'np_topo_id':3,
        'subspace':0,
        'auto_zoom_x':0,
        'auto_zoom_y':0,
        'auto_zoom_z':0,
        'trigger_hi_x':0,
        'trigger_hi_y':0,
        'trigger_hi_z':0,
        'trigger_lo_x':0,
        'trigger_lo_y':0,
        'trigger_lo_z':1,
        'set_hi_x':0,
        'set_hi_y':0,
        'set_hi_z':0,
        'set_lo_x':0,
        'set_lo_y':0,
        'set_lo_z':0,
        'proximity_x':0,
        'proximity_y':0,
        'proximity_z':0,
        'proximity_mode_x':0,
        'proximity_mode_y':0,
        'proximity_mode_z':0,
        'segments_x':12,
        'segments_y':6,
        'segments_z':1,
        'tag_mode':65536017,
        'np_format_id':0,
        'np_table_id':ser_year_num,
        'record_id':ser_year_num,
        'size':420 

    }

    ser_year_tag[country] = {
                            'np_tag_id':ser_year_num,
                            'record_id':ser_year_num,
                            'table_id': ser_year_num,
                            'title': year,
                            'description': str(year) + " - " + str(val)
    }

    ser_year_num += 1

# %%
cdict_node
# Out:
# {'Albania': {'np_node_id': 2,
#   'type': 5,
#   'np_data_id': 2,
#   'selected': 0,
#   'parent_id': 0,
#   'branch_level': 1,
#   'child_id': 0,
#   'np_tag_id': 2,
#   'np_palette_id': 0,
#   'np_ch_in_id': 0,
#   'np_ch_out_id': 0,
#   'ch_sync_time': 0,
#   'np_palette_id_alt': 0,
#   'np_color_id_alt': 19,
#   'aux_a_x': 330,
#   'aux_a_y': 1,
#   'aux_a_z': 0.01,
#   'aux_b_x': 0,
#   'aux_b_y': 1,
#   'aux_b_z': 1,
#   'color_alpha_alt': 255,
#   'rotate_vec_x': 0,
#   'rotate_vec_y': 1,
#   'rotate_vec_z': 0,
#   'rotate_vec_s': 0,
#   'scale_x': 5.5,
#   'scale_y': 5.5,
#   'scale_z': 5.5,
#   'translate_x': 20,
#   'translate_y': 41.0,
#   'translate_z': 0,
#   'tag_offset_x': 0,
#   'tag_offset_y': 0,
#   'tag_offset_z': 5.5,
#   'rotate_rate_x': 0,
#   'rotate_rate_y': 0,
#   'rotate_rate_z': 0,
#   'rotate_x': 0,
#   'rotate_y': 0,
#   'rotate_z': 0,
#   'scale_rate_x': 0,
#   'scale_rate_y': 0,
#   'scale_rate_z': 0,
#   'translate_rate_x': 0,
# ...

# %%
c_ind_dict_node
# Out:
# {'Albania': {'np_node_id': 101,
#   'type': 5,
#   'np_data_id': 101,
#   'selected': 0,
#   'parent_id': 2,
#   'branch_level': 2,
#   'child_id': 0,
#   'np_tag_id': 101,
#   'np_palette_id': 0,
#   'np_ch_in_id': 0,
#   'np_ch_out_id': 0,
#   'ch_sync_time': 0,
#   'np_palette_id_alt': 0,
#   'np_color_id_alt': 19,
#   'aux_a_x': 330,
#   'aux_a_y': 1,
#   'aux_a_z': 0.01,
#   'aux_b_x': 0,
#   'aux_b_y': 1,
#   'aux_b_z': 1,
#   'color_alpha_alt': 255,
#   'rotate_vec_x': 0,
#   'rotate_vec_y': 1,
#   'rotate_vec_z': 0,
#   'rotate_vec_s': 0,
#   'scale_x': 0.8,
#   'scale_y': 0.8,
#   'scale_z': 0.8,
#   'translate_x': 0,
#   'translate_y': 0,
#   'translate_z': 0,
#   'tag_offset_x': 0,
#   'tag_offset_y': 1,
#   'tag_offset_z': 0,
#   'rotate_rate_x': 0,
#   'rotate_rate_y': 0,
#   'rotate_rate_z': 0,
#   'rotate_x': 0,
#   'rotate_y': 0,
#   'rotate_z': 0,
#   'scale_rate_x': 0,
#   'scale_rate_y': 0,
#   'scale_rate_z': 0,
#   'translate_rate_x': 0,
# ...

# %%
c_ind_dict_tag
# Out:
# {'Albania': {'np_tag_id': 101,
#   'record_id': 101,
#   'table_id': 101,
#   'title': '1.1',
#   'description': '1.1 - Albania'},
#  'Malawi': {'np_tag_id': 104,
#   'record_id': 104,
#   'table_id': 104,
#   'title': '1.2',
#   'description': '1.2 - Malawi'}}

# %%
cdict_node
# Out:
# {'Albania': {'np_node_id': 2,
#   'type': 5,
#   'np_data_id': 2,
#   'selected': 0,
#   'parent_id': 0,
#   'branch_level': 1,
#   'child_id': 0,
#   'np_tag_id': 2,
#   'np_palette_id': 0,
#   'np_ch_in_id': 0,
#   'np_ch_out_id': 0,
#   'ch_sync_time': 0,
#   'np_palette_id_alt': 0,
#   'np_color_id_alt': 19,
#   'aux_a_x': 330,
#   'aux_a_y': 1,
#   'aux_a_z': 0.01,
#   'aux_b_x': 0,
#   'aux_b_y': 1,
#   'aux_b_z': 1,
#   'color_alpha_alt': 255,
#   'rotate_vec_x': 0,
#   'rotate_vec_y': 1,
#   'rotate_vec_z': 0,
#   'rotate_vec_s': 0,
#   'scale_x': 5.5,
#   'scale_y': 5.5,
#   'scale_z': 5.5,
#   'translate_x': 20,
#   'translate_y': 41.0,
#   'translate_z': 0,
#   'tag_offset_x': 0,
#   'tag_offset_y': 0,
#   'tag_offset_z': 5.5,
#   'rotate_rate_x': 0,
#   'rotate_rate_y': 0,
#   'rotate_rate_z': 0,
#   'rotate_x': 0,
#   'rotate_y': 0,
#   'rotate_z': 0,
#   'scale_rate_x': 0,
#   'scale_rate_y': 0,
#   'scale_rate_z': 0,
#   'translate_rate_x': 0,
# ...

# %%
cdict_tag
# Out:
# {'Albania': {'np_tag_id': 2,
#   'record_id': 2,
#   'table_id': 2,
#   'title': 'Albania',
#   'description': 'Albania'},
#  'Malawi': {'np_tag_id': 5,
#   'record_id': 5,
#   'table_id': 5,
#   'title': 'Malawi',
#   'description': 'Malawi'}}

# %%
ser_dict_node
# Out:
# {'Albania': {'np_node_id': 1001,
#   'type': 5,
#   'np_data_id': 1001,
#   'selected': 0,
#   'parent_id': 101,
#   'branch_level': 3,
#   'child_id': 0,
#   'np_tag_id': 1001,
#   'np_palette_id': 0,
#   'np_ch_in_id': 0,
#   'np_ch_out_id': 0,
#   'ch_sync_time': 0,
#   'np_palette_id_alt': 0,
#   'np_color_id_alt': 19,
#   'aux_a_x': 330,
#   'aux_a_y': 1,
#   'aux_a_z': 0.01,
#   'aux_b_x': 0,
#   'aux_b_y': 1,
#   'aux_b_z': 1,
#   'color_alpha_alt': 255,
#   'rotate_vec_x': 0,
#   'rotate_vec_y': 1,
#   'rotate_vec_z': 0,
#   'rotate_vec_s': 0,
#   'scale_x': 0.8,
#   'scale_y': 0.8,
#   'scale_z': 0.8,
#   'translate_x': 0,
#   'translate_y': 0,
#   'translate_z': 0,
#   'tag_offset_x': 0,
#   'tag_offset_y': 1,
#   'tag_offset_z': 0,
#   'rotate_rate_x': 0,
#   'rotate_rate_y': 0,
#   'rotate_rate_z': 0,
#   'rotate_x': 0,
#   'rotate_y': 0,
#   'rotate_z': 0,
#   'scale_rate_x': 0,
#   'scale_rate_y': 0,
#   'scale_rate_z': 0,
#   'translate_rate_x': 0,
# ...

# %%
ser_dict_tag
# Out:
# {'Albania': {'np_tag_id': 1001,
#   'record_id': 1001,
#   'table_id': 1001,
#   'title': 'S1',
#   'description': '1.1 - S1'},
#  'Malawi': {'np_tag_id': 1004,
#   'record_id': 1004,
#   'table_id': 1004,
#   'title': 'S3',
#   'description': '1.2 - S3'}}

# %%
ser_year_node
# Out:
# {'Albania': {'np_node_id': 5001,
#   'type': 5,
#   'np_data_id': 5001,
#   'selected': 0,
#   'parent_id': 1001,
#   'branch_level': 4,
#   'child_id': 0,
#   'np_tag_id': 5001,
#   'np_palette_id': 0,
#   'np_ch_in_id': 0,
#   'np_ch_out_id': 0,
#   'ch_sync_time': 0,
#   'np_palette_id_alt': 0,
#   'np_color_id_alt': 19,
#   'aux_a_x': 330,
#   'aux_a_y': 1,
#   'aux_a_z': 0.01,
#   'aux_b_x': 0,
#   'aux_b_y': 1,
#   'aux_b_z': 1,
#   'color_alpha_alt': 255,
#   'rotate_vec_x': 0,
#   'rotate_vec_y': 1,
#   'rotate_vec_z': 0,
#   'rotate_vec_s': 0,
#   'scale_x': 0.8,
#   'scale_y': 0.8,
#   'scale_z': 0.8,
#   'translate_x': 0,
#   'translate_y': 0,
#   'translate_z': 0,
#   'tag_offset_x': 0,
#   'tag_offset_y': 1,
#   'tag_offset_z': 0,
#   'rotate_rate_x': 0,
#   'rotate_rate_y': 0,
#   'rotate_rate_z': 0,
#   'rotate_x': 0,
#   'rotate_y': 0,
#   'rotate_z': 0,
#   'scale_rate_x': 0,
#   'scale_rate_y': 0,
#   'scale_rate_z': 0,
#   'translate_rate_x': 0,
# ...

# %%
ser_year_tag
# Out:
# {'Albania': {'np_tag_id': 5001,
#   'record_id': 5001,
#   'table_id': 5001,
#   'title': 2022,
#   'description': '2022 - 6.8'},
#  'Malawi': {'np_tag_id': 5004,
#   'record_id': 5004,
#   'table_id': 5004,
#   'title': 2023,
#   'description': '2023 - 1.0'}}

# %%
tag_df1 = pd.DataFrame.from_dict(c_ind_dict_tag, orient='index').reset_index()
tag_df1.columns = ['Country', 'np_tag_id', 'record_id', 'table_id', 'title', 'description']
tag_df1.drop('Country', inplace=True, axis=1)


tag_df2 = pd.DataFrame.from_dict(cdict_tag, orient='index').reset_index()
tag_df2.columns = ['Country', 'np_tag_id', 'record_id', 'table_id', 'title', 'description']
tag_df2.drop('Country', inplace=True, axis=1)

tag_df3 = pd.DataFrame.from_dict(ser_dict_tag, orient='index').reset_index()
tag_df3.columns = ['Country', 'np_tag_id', 'record_id', 'table_id', 'title', 'description']
tag_df3.drop('Country', inplace=True, axis=1)

tag_df4 = pd.DataFrame.from_dict(ser_year_tag, orient='index').reset_index()
tag_df4.columns = ['Country', 'np_tag_id', 'record_id', 'table_id', 'title', 'description']
tag_df4.drop('Country', inplace=True, axis=1)

tag_comb_df = pd.concat([tag_df1, tag_df2, tag_df3, tag_df4])
tag_comb_df
# Out:
#    np_tag_id  record_id  table_id    title    description
# 0        101        101       101      1.1  1.1 - Albania
# 1        104        104       104      1.2   1.2 - Malawi
# 0          2          2         2  Albania        Albania
# 1          5          5         5   Malawi         Malawi
# 0       1001       1001      1001       S1       1.1 - S1
# 1       1004       1004      1004       S3       1.2 - S3
# 0       5001       5001      5001     2022     2022 - 6.8
# 1       5004       5004      5004     2023     2023 - 1.0

# %%
node_df = pd.DataFrame.from_dict(cdict_node, orient='index').reset_index()
node_df.columns = [
    'Country','np_node_id','type','np_data_id','selected','parent_id','branch_level', 'child_id', 'np_tag_id','np_palette_id',
    'np_ch_in_id', 'np_ch_out_id', 'ch_sync_time','np_palette_id_alt','np_color_id_alt','aux_a_x', 'aux_a_y', 'aux_a_z', 
    'aux_b_x', 'aux_b_y', 'aux_b_z', 'color_alpha_alt', 'rotate_vec_x', 'rotate_vec_y', 'rotate_vec_z', 'rotate_vec_s',
    'scale_x', 'scale_y','scale_z', 'translate_x', 'translate_y', 'translate_z', 'tag_offset_x', 'tag_offset_y', 'tag_offset_z',
    'rotate_rate_x', 'rotate_rate_y', 'rotate_rate_z', 'rotate_x', 'rotate_y', 'rotate_z', 'scale_rate_x', 'scale_rate_y',
    'scale_rate_z', 'translate_rate_x', 'translate_rate_y', 'translate_rate_z', 'translate_vec_x', 'translate_vec_y',
    'translate_vec_z', 'np_material_id', 'np_geometry_id', 'line_width', 'point_size', 'ratio', 'np_color_id',
    'color_r','color_g', 'color_b', 'color_a', 'color_fade', 'np_texture_id', 'hide', 'freeze', 'np_topo_id', 'subspace',
    'auto_zoom_x', 'auto_zoom_y', 'auto_zoom_z', 'trigger_hi_x', 'trigger_hi_y', 'trigger_hi_z', 'trigger_lo_x', 
    'trigger_lo_y', 'trigger_lo_z', 'set_hi_x', 'set_hi_y', 'set_hi_z', 'set_lo_x', 'set_lo_y', 'set_lo_z','proximity_x',
    'proximity_y', 'proximity_z', 'proximity_mode_x', 'proximity_mode_y', 'proximity_mode_z', 'segments_x', 'segments_y',
    'segments_z', 'tag_mode', 'np_format_id', 'np_table_id', 'record_id', 'size']
node_df.drop('Country', inplace=True, axis=1)

node_df1 = pd.DataFrame.from_dict(c_ind_dict_node, orient='index').reset_index()
node_df1.columns = [
    'Country','np_node_id','type','np_data_id','selected','parent_id','branch_level', 'child_id', 'np_tag_id','np_palette_id',
    'np_ch_in_id', 'np_ch_out_id', 'ch_sync_time','np_palette_id_alt','np_color_id_alt','aux_a_x', 'aux_a_y', 'aux_a_z', 
    'aux_b_x', 'aux_b_y', 'aux_b_z', 'color_alpha_alt', 'rotate_vec_x', 'rotate_vec_y', 'rotate_vec_z', 'rotate_vec_s',
    'scale_x', 'scale_y','scale_z', 'translate_x', 'translate_y', 'translate_z', 'tag_offset_x', 'tag_offset_y', 'tag_offset_z',
    'rotate_rate_x', 'rotate_rate_y', 'rotate_rate_z', 'rotate_x', 'rotate_y', 'rotate_z', 'scale_rate_x', 'scale_rate_y',
    'scale_rate_z', 'translate_rate_x', 'translate_rate_y', 'translate_rate_z', 'translate_vec_x', 'translate_vec_y',
    'translate_vec_z', 'np_material_id', 'np_geometry_id', 'line_width', 'point_size', 'ratio', 'np_color_id',
    'color_r','color_g', 'color_b', 'color_a', 'color_fade', 'np_texture_id', 'hide', 'freeze', 'np_topo_id', 'subspace',
    'auto_zoom_x', 'auto_zoom_y', 'auto_zoom_z', 'trigger_hi_x', 'trigger_hi_y', 'trigger_hi_z', 'trigger_lo_x', 
    'trigger_lo_y', 'trigger_lo_z', 'set_hi_x', 'set_hi_y', 'set_hi_z', 'set_lo_x', 'set_lo_y', 'set_lo_z','proximity_x',
    'proximity_y', 'proximity_z', 'proximity_mode_x', 'proximity_mode_y', 'proximity_mode_z', 'segments_x', 'segments_y',
    'segments_z', 'tag_mode', 'np_format_id', 'np_table_id', 'record_id', 'size']
node_df1.drop('Country', inplace=True, axis=1)

node_df2 = pd.DataFrame.from_dict(ser_dict_node, orient='index').reset_index()
node_df2.columns = [
    'Country','np_node_id','type','np_data_id','selected','parent_id','branch_level', 'child_id', 'np_tag_id','np_palette_id',
    'np_ch_in_id', 'np_ch_out_id', 'ch_sync_time','np_palette_id_alt','np_color_id_alt','aux_a_x', 'aux_a_y', 'aux_a_z', 
    'aux_b_x', 'aux_b_y', 'aux_b_z', 'color_alpha_alt', 'rotate_vec_x', 'rotate_vec_y', 'rotate_vec_z', 'rotate_vec_s',
    'scale_x', 'scale_y','scale_z', 'translate_x', 'translate_y', 'translate_z', 'tag_offset_x', 'tag_offset_y', 'tag_offset_z',
    'rotate_rate_x', 'rotate_rate_y', 'rotate_rate_z', 'rotate_x', 'rotate_y', 'rotate_z', 'scale_rate_x', 'scale_rate_y',
    'scale_rate_z', 'translate_rate_x', 'translate_rate_y', 'translate_rate_z', 'translate_vec_x', 'translate_vec_y',
    'translate_vec_z', 'np_material_id', 'np_geometry_id', 'line_width', 'point_size', 'ratio', 'np_color_id',
    'color_r','color_g', 'color_b', 'color_a', 'color_fade', 'np_texture_id', 'hide', 'freeze', 'np_topo_id', 'subspace',
    'auto_zoom_x', 'auto_zoom_y', 'auto_zoom_z', 'trigger_hi_x', 'trigger_hi_y', 'trigger_hi_z', 'trigger_lo_x', 
    'trigger_lo_y', 'trigger_lo_z', 'set_hi_x', 'set_hi_y', 'set_hi_z', 'set_lo_x', 'set_lo_y', 'set_lo_z','proximity_x',
    'proximity_y', 'proximity_z', 'proximity_mode_x', 'proximity_mode_y', 'proximity_mode_z', 'segments_x', 'segments_y',
    'segments_z', 'tag_mode', 'np_format_id', 'np_table_id', 'record_id', 'size']
node_df2.drop('Country', inplace=True, axis=1)

node_df3 = pd.DataFrame.from_dict(ser_year_node, orient='index').reset_index()
node_df3.columns = [
    'Country','np_node_id','type','np_data_id','selected','parent_id','branch_level', 'child_id', 'np_tag_id','np_palette_id',
    'np_ch_in_id', 'np_ch_out_id', 'ch_sync_time','np_palette_id_alt','np_color_id_alt','aux_a_x', 'aux_a_y', 'aux_a_z', 
    'aux_b_x', 'aux_b_y', 'aux_b_z', 'color_alpha_alt', 'rotate_vec_x', 'rotate_vec_y', 'rotate_vec_z', 'rotate_vec_s',
    'scale_x', 'scale_y','scale_z', 'translate_x', 'translate_y', 'translate_z', 'tag_offset_x', 'tag_offset_y', 'tag_offset_z',
    'rotate_rate_x', 'rotate_rate_y', 'rotate_rate_z', 'rotate_x', 'rotate_y', 'rotate_z', 'scale_rate_x', 'scale_rate_y',
    'scale_rate_z', 'translate_rate_x', 'translate_rate_y', 'translate_rate_z', 'translate_vec_x', 'translate_vec_y',
    'translate_vec_z', 'np_material_id', 'np_geometry_id', 'line_width', 'point_size', 'ratio', 'np_color_id',
    'color_r','color_g', 'color_b', 'color_a', 'color_fade', 'np_texture_id', 'hide', 'freeze', 'np_topo_id', 'subspace',
    'auto_zoom_x', 'auto_zoom_y', 'auto_zoom_z', 'trigger_hi_x', 'trigger_hi_y', 'trigger_hi_z', 'trigger_lo_x', 
    'trigger_lo_y', 'trigger_lo_z', 'set_hi_x', 'set_hi_y', 'set_hi_z', 'set_lo_x', 'set_lo_y', 'set_lo_z','proximity_x',
    'proximity_y', 'proximity_z', 'proximity_mode_x', 'proximity_mode_y', 'proximity_mode_z', 'segments_x', 'segments_y',
    'segments_z', 'tag_mode', 'np_format_id', 'np_table_id', 'record_id', 'size']
node_df3.drop('Country', inplace=True, axis=1)

node_comb_df = pd.concat([node_df, node_df1, node_df2, node_df3])
node_comb_df
# Out:
#    np_node_id  type  np_data_id  selected  parent_id  branch_level  child_id  \
# 0           2     5           2         0          0             1         0
# 1           5     5           5         0          0             1         0
# 0         101     5         101         0          2             2         0
# 1         104     5         104         0          5             2         0
# 0        1001     5        1001         0        101             3         0
# 1        1004     5        1004         0        104             3         0
# 0        5001     5        5001         0       1001             4         0
# 1        5004     5        5004         0       1004             4         0
#
#    np_tag_id  np_palette_id  np_ch_in_id  ...  proximity_mode_y  \
# 0          2              0            0  ...                 0
# 1          5              0            0  ...                 0
# 0        101              0            0  ...                 0
# ...

# %%
tag_comb_df.to_csv("g1_np_tag_v3.csv", index = False)
node_comb_df.to_csv("g1_np_node_v3.csv", index = False)

# %%
node_df
# Out:
#    np_node_id  type  np_data_id  selected  parent_id  branch_level  child_id  \
# 0           2     5           2         0          0             1         0
# 1           5     5           5         0          0             1         0
#
#    np_tag_id  np_palette_id  np_ch_in_id  ...  proximity_mode_y  \
# 0          2              0            0  ...                 0
# 1          5              0            0  ...                 0
#
#    proximity_mode_z  segments_x  segments_y  segments_z  tag_mode  \
# 0                 0          12           6           1  65536017
# 1                 0          12           6           1  65536017
#
#    np_format_id  np_table_id  record_id  size
# 0             0            2          2   420
# 1             0            5          5   420
#
# [2 rows x 94 columns]
